# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# # Importando dados

# %%
df = pd.read_csv('../../data/raw/exames.csv', )
df
# Out:
#            id diagnostico  exame_1  exame_2  exame_3  exame_4  exame_5  \
# 0      842302           M    17.99    10.38   122.80   103.78   1001.0
# 1      842517           M    20.57    17.77   132.90   103.78   1326.0
# 2    84300903           M    19.69    21.25   130.00   103.78   1203.0
# 3    84348301           M    11.42    20.38    77.58   103.78    386.1
# 4    84358402           M    20.29    14.34   135.10   103.78   1297.0
# ..        ...         ...      ...      ...      ...      ...      ...
# 564    926424           M    21.56    22.39   142.00   103.78   1479.0
# 565    926682           M    20.13    28.25   131.20   103.78   1261.0
# 566    926954           M    16.60    28.08   108.30   103.78    858.1
# 567    927241           M    20.60    29.33   140.10   103.78   1265.0
# 568     92751           B     7.76    24.54    47.92   103.78    181.0
#
#      exame_6  exame_7  exame_8  ...  exame_24  exame_25  exame_26  exame_27  \
# ...

# %% [markdown]
# # Analises

# %% [markdown]
# ## Valores ausentes

# %% [markdown]
# ### Anotacoes
#
# - Apenas uma variavel possui valores NaN, seria a variavel: exames_33
# - Foram identificados 419 valores NaN nessa variavel
# - Temos 569 registros totais na base e 419 registros NaN para variavel exames_33
#     - Representando: (419/569)*100 = 73% dos dados
#     - Devido porcentagem alta, nao avaliaria variavel e a descartaria, documentando neste projeto o motivo.

# %%
df.isna().sum()
# Out:
# id               0
# diagnostico      0
# exame_1          0
# exame_2          0
# exame_3          0
# exame_4          0
# exame_5          0
# exame_6          0
# exame_7          0
# exame_8          0
# exame_9          0
# exame_10         0
# exame_11         0
# exame_12         0
# exame_13         0
# exame_14         0
# exame_15         0
# exame_16         0
# exame_17         0
# exame_18         0
# exame_19         0
# exame_20         0
# exame_21         0
# exame_22         0
# exame_23         0
# exame_24         0
# exame_25         0
# exame_26         0
# exame_27         0
# exame_28         0
# exame_29         0
# exame_30         0
# exame_31         0
# exame_32         0
# exame_33       419
# dtype: int64

# %% [markdown]
# ## Heatmap de correlacao das variaveis

# %%
# selecionando variaveis numericas de df
df_num = df.select_dtypes(include='number')

# criando matriz de correlacao das variaveis numericas
matriz_corr = df_num.corr()

# criando grafico de correlacao de variaveis com matriz de correlacao calculada
fig_heatmap = px.imshow(
    matriz_corr,
    title='Heatmap de correlacao das variaveis',
    text_auto=True,
    height=1200
)

fig_heatmap.show()
